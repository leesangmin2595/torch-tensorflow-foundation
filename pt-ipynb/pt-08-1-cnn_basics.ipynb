# %% [markdown]
# ## CNN Basics : PyTorch

# %%
import torch
from torch import nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  ### A Gray Image

# %%
print("************* An Image - Gray *****************")
image = torch.FloatTensor([[[[1, 2, 3],
                   [4, 5, 6], 
                   [7, 8, 9]]]])
# print("imag:\n", image)
print("image.shape", image.shape)
plt.imshow(image.reshape(3,3), cmap='Greys')
plt.show()
# Out:
# ************* An Image - Gray *****************
# image.shape torch.Size([1, 1, 3, 3])

# %% [markdown]
# ### A Filter

# %%
weight = torch.FloatTensor([[[[1.,1.],
                      [1.,1.]]]])
print("weight.shape", weight.shape)
# Out:
# weight.shape torch.Size([1, 1, 2, 2])

# %% [markdown]
# ### 2D Convolution with VALID option

# %%
print("************* Conv2D - 1 filter - VALID *****************")

conv2d_img = F.conv2d(image, weight, stride=1, padding='valid')
print("conv2d_img.shape", conv2d_img.shape)
#conv2d_img = np.swapaxes(conv2d_img, 0, 3)

print(conv2d_img.shape)
for i, one_img in enumerate(conv2d_img):
    print(one_img.view(2,2))
    plt.subplot(1,2,i+1), plt.imshow(one_img.reshape(2,2), cmap='gray')
    
plt.show()
# Out:
# ************* Conv2D - 1 filter - VALID *****************
# conv2d_img.shape torch.Size([1, 1, 2, 2])
# torch.Size([1, 1, 2, 2])
# tensor([[12., 16.],
#         [24., 28.]])

# %% [markdown]
# ### 2D Convolution with SAME option

# %%
print("************* Conv2D - 1 filter - SAME *****************")

print("image.shape", image.shape)
print("weight.shape", weight.shape)

conv2d_img = F.conv2d(image, weight, stride=1, padding='same')
print("conv2d_img.shape", conv2d_img.shape)
#conv2d_img = np.swapaxes(conv2d_img, 0, 3)

for i, one_img in enumerate(conv2d_img):
    print(one_img.reshape(3,3))
    plt.subplot(1,2,i+1), plt.imshow(one_img.reshape(3,3), cmap='gray')
    
plt.show()
# Out:
# ************* Conv2D - 1 filter - SAME *****************
# image.shape torch.Size([1, 1, 3, 3])
# weight.shape torch.Size([1, 1, 2, 2])
# conv2d_img.shape torch.Size([1, 1, 3, 3])
# tensor([[12., 16.,  9.],
#         [24., 28., 15.],
#         [15., 17.,  9.]])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  /pytorch/aten/src/ATen/native/Convolution.cpp:660.)

# %% [markdown]
# ### 3 Filters

# %%
weight = torch.FloatTensor([[[[ 1.,  1.], [ 1.,  1.]],
         [[10., 10.], [10., 10.]],
         [[-1., -1.], [-1., -1.]]]])
print("weight.shape", weight.shape)

#weight = weight.permute(2, 3, 0, 1)
#print("weight.shape", weight.shape)
#print(weight)
# Out:
# weight.shape torch.Size([1, 3, 2, 2])

# %% [markdown]
# ### 2D Convolution with 3 Filters

# %%
print("************* Conv2D - 3 filters *****************")
print("image.shape", image.shape)

conv2d_img = F.conv2d(image, weight, stride=1, padding='same', gropus=3)
print("conv2d_img.shape", conv2d_img.shape)

for i, one_img in enumerate(conv2d_img):
    print(one_img.reshape(3,3))
    plt.subplot(1,3,i+1), plt.imshow(one_img.reshape(3,3), cmap='gray')
    
plt.show()
# Out:
# ************* Conv2D - 3 filters *****************
# image.shape torch.Size([1, 1, 3, 3])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e57c6c5bd63f> in <module>()
#       2 print("image.shape", image.shape)
#       3
# ----> 4 conv2d_img = F.conv2d(image, weight, stride=1, padding='same', gropus=3)
#       5 print("conv2d_img.shape", conv2d_img.shape)
#       6
#
# TypeError: conv2d() received an invalid combination of arguments - got (Tensor, Tensor, gropus=int, stride=int, padding=str), but expected one of:
#  * (Tensor input, Tensor weight, Tensor bias, tuple of ints stride, tuple of ints padding, tuple of ints dilation, int groups)
#  * (Tensor input, Tensor weight, Tensor bias, tuple of ints stride, str padding, tuple of ints dilation, int groups)

# %% [markdown]
# ### Max Pooling with VALID option

# %%
print("************* Max Pooling *****************")
image = np.array([[[[4],[3]],
                    [[2],[1]]]], dtype=np.float32)
pool = tf.nn.max_pool(image, ksize=[1, 2, 2, 1],
                    strides=[1, 1, 1, 1], padding='VALID')
print(pool.shape)
#print(sess.run(pool))

# %% [markdown]
# ### Max Pooling with SAME option

# %%
print("************* Max Pooling - SAME *****************")
image = np.array([[[[4],[3]],
                    [[2],[1]]]], dtype=np.float32)
pool = tf.nn.max_pool(image, ksize=[1, 2, 2, 1],
                    strides=[1, 1, 1, 1], padding='SAME')
print(pool.shape)
#print(sess.run(pool))

# %% [markdown]
# ### MNIST Data

# %%
print("************* MNIST *****************")
(train_x,train_y), (test_x, test_y) = tf.keras.datasets.mnist.load_data()
img = train_x[0]
plt.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# ### 5개 3x3 Filters

# %%
W1 = tf.Variable(tf.random.normal([3, 3, 1, 5], stddev=0.01))

# %% [markdown]
# ### 2D Convolution with 5 Filters

# %%
print("************* MNIST - Conv2D *****************")
img = img.reshape(-1,28,28,1)

conv2d_img = tf.nn.conv2d(img, W1, strides=[1, 2, 2, 1], padding='SAME')
print(conv2d_img.shape)

conv2d_disp = np.swapaxes(conv2d_img, 0, 3)
for i, one_img in enumerate(conv2d_disp):
    plt.subplot(1,5,i+1), plt.imshow(one_img.reshape(14,14), cmap='gray')
    
plt.show()

# %% [markdown]
# ### Max Pooling for 5 Con2D Images

# %%
print("************* MNIST - Max Pooling *****************") 
pool_img = tf.nn.max_pool(conv2d_img, ksize=[1, 2, 2, 1], strides=[
                        1, 2, 2, 1], padding='SAME')
print(pool_img.shape)

pool_disp = np.swapaxes(pool_img, 0, 3)
for i, one_img in enumerate(pool_disp):
#    print(i, one_img.shape)
    plt.subplot(1,5,i+1), plt.imshow(one_img.reshape(7, 7), cmap='gray')
    
plt.show()
